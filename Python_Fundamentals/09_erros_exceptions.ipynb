# %% [markdown]
# ## try and Exceptions

# %%
try:
    age = int(input("Age: "))
    income = 243
    risk = income/age
    print(age)
except ZeroDivisionError:
    print("age can not be 0")
except ValueError:
    print("Invalid age")
# Out:
# Invalid age

# %%
x = 5
x // 10
print(x)
# Out:
# 5
