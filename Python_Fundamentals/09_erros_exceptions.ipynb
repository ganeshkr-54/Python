# %% [markdown]
# ## try and Exceptions

# %%
try:
    age = int(input("Age: "))
    income = 243
    risk = income/age
    print(age)
except ZeroDivisionError:
    print("age can not be 0")
except ValueError:
    print("Invalid age")
# Out:
# Invalid age

# %%
nums = [2,7,11,15]
target = 9

for i in range(len(nums)):
    sum = nums[i] + nums[i+1]
    if sum == target:
        print(i,i+1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       2 target = 9
#       4 for i in range(len(nums)):
# ----> 5     sum = nums(i) + nums(i+1)
#       6     if sum == target:
#       7         print(i,i+1)
#
# TypeError: 'list' object is not callable
