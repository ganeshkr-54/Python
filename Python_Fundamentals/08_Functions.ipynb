# %% [markdown]
# ## Functions

# %%
def greet():
    print("Hello Good Morning :) ")

greet()
# Out:
# Hello Good Morning :)

# %% [markdown]
# ## Parameters

# %%
def greet(name):
    print(f"Hello Good Morning :) {name}")

greet("ganesh")
# Out:
# Hello Good Morning :) ganesh

# %%
#Positional Argument

def greet(name, pet):
    print(f"Hello {name} is your pet {pet}")
greet("ganesh",25) #here  order of position is important
# Out:
# Hello ganesh is your age 25

# %% [markdown]
# ## KeyWord Arguments

# %%
#KeyWord Argument

def greet(name, pet):
    print(f"Hello {name} is your pet {pet}")
greet(pet="dog", name="ganesh") # if we intend to change order of position the we can use keyword argument
# Out:
# Hello ganesh is your pet dog

# %% [markdown]
# ## Return

# %%
def sum(a,b):
    return a+b
sum(2,3)
# Out:
# 5

# %% [markdown]
# ## Reusable Functions

# %%
def emoji_con(message):
   words = message.split(" ")
   emojis = {
    ":)" : "😀",
    ":(" : "😞"
}
   output = ''
   for word in words:
        output += emojis.get(word, word) + ' ' 
   return output

message = input(">")

print(emoji_con(message))
# Out:
# This is Ganesh 😀
